# %%
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
clusters = [[2, 2, 2], [7, 7, 7], [5, 13, 13]]

# %%
X, _ = make_blobs(n_samples = 150, centers = clusters, cluster_std = .60)

# %%
fig = plt.figure()
 
ax = fig.add_subplot(111, projection ='3d')
 
ax.scatter(X[:, 0], X[:, 1], X[:, 2], marker ='o')
plt.show()

# %%
from sklearn.cluster import estimate_bandwidth

# %%
bandwidth= estimate_bandwidth(X, quantile=0.20,n_samples=500)

# %%
ms=MeanShift(bandwidth=bandwidth,bin_seeding=True)
ms.fit(X)
culser_centers=ms.cluster_centers_
labels=ms.labels_
cluster_label= np.unique(labels)
n_clusters=len(cluster_label)
n_clusters
# Out:
# 3

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection ='3d')
 
ax.scatter(culser_centers[:, 0], culser_centers[:, 1], culser_centers[:, 2], marker ='o',c='r',s=300, linewidth=5,zorder=10)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], marker ='o')
plt.show()
